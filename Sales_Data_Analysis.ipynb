# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Load Data Set

# %%
df=pd.read_csv('/content/sales_data.csv')

# %%
df
# Out:
#            date     product     category   price  quantity  revenue
# 0    2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1    2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2    2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3    2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4    2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ..          ...         ...          ...     ...       ...      ...
# 364  2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [369 rows x 6 columns]

# %% [markdown]
# # 1: What was the total revenue generated by the company over the course of the year?

# %%
df2 = df["revenue"].sum()

# %%
df2
# Out:
# 758330.0

# %% [markdown]
# # 2:Which product had the highest revenue? How much revenue did it generate?

# %%
newdf = df.groupby("product")[['revenue']].sum()
newdf2 = newdf.max()

# %%
newdf
# Out:
#              revenue
# product
# Backpack     20400.0
# Coat         33800.0
# Headphones   18000.0
# Hoodie       21000.0
# Jeans        20650.0
# Laptop        6000.0
# Smartphone  434400.0
# Smartwatch   58800.0
# Sneakers     21600.0
# Speaker      39680.0
# T-Shirt      20100.0
# Tablet       18000.0
# Wallet       13200.0
# Watch        32700.0

# %%
newdf = df.groupby("product")[['revenue']].sum()
newdf2 = newdf.max()
result = newdf.idxmax()
# Display result
print(newdf2,"product had the highest revenue:\n",result)
# Out:
# revenue    434400.0
# dtype: float64 product had the highest revenue:
#  revenue    Smartphone
# dtype: object

# %%
import matplotlib.pyplot as plt
# Plot the revenue of each product as a bar chart
newdf.plot(kind="bar", rot=27)
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.title("Revenue by Product")
plt.show()

# %% [markdown]
# # 3:What was the average price of a product sold by the company?

# %%
avrdf = df["price"].mean()
avrdf
# Out:
# 211.22615803814713

# %% [markdown]
# # 4:What was the total quantity of products sold by the company?

# %%
totaldf = df["quantity"].sum()
totaldf
# Out:
# 5360.0

# %% [markdown]
# # 5:Which category had the highest revenue? How much revenue did it generate?

# %%
newdf = df.groupby("category")[['revenue']].sum()
newdf2 = newdf.max()
result = newdf.idxmax()
# Display result
print(newdf2,"category had the highest revenue:\n",result)
# Out:
# revenue    516080.0
# dtype: float64 category had the highest revenue:
#  revenue    Electronics
# dtype: object

# %% [markdown]
# # 6:What was the average revenue per sale?

# %%
newdf = df.groupby("product")[['revenue']].mean()
newdf
# Out:
#                 revenue
# product
# Backpack     850.000000
# Coat         965.714286
# Headphones  1384.615385
# Hoodie       875.000000
# Jeans        860.416667
# Laptop      6000.000000
# Smartphone  5297.560976
# Smartwatch  1680.000000
# Sneakers     900.000000
# Speaker     1587.200000
# T-Shirt      528.947368
# Tablet      2000.000000
# Wallet      1100.000000
# Watch       1486.363636

# %% [markdown]
# # 7:What was the total revenue generated in each quarter of the year? (i.e. Q1, Q2, Q3, Q4)

# %%
# convert to pandas datetime
df['date'] = pd.to_datetime(df['date'])
# using the quarter property
df['Quarter'] = df['date'].dt.quarter
# display the dataframe
print(df)
# Out:
#           date     product     category   price  quantity  revenue  Quarter
# 0   2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0        1
# 1   2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0        1
# 2   2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0        1
# 3   2022-01-03  Headphones  Electronics   100.0      20.0   2000.0        1
# 4   2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0        1
# ..         ...         ...          ...     ...       ...      ...      ...
# 364 2022-12-27       Watch  Accessories   150.0       5.0    750.0        4
# 365 2022-12-28        Coat     Clothing   100.0       5.0    500.0        4
# 366 2022-12-29  Headphones  Electronics   100.0      10.0   1000.0        4
# 367 2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0        4
# 368 2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0        4
#
# [369 rows x 7 columns]

# %%
qrdf = df.groupby("Quarter")[['revenue']].sum()
qrdf
# Out:
#           revenue
# Quarter
# 1        182100.0
# 2        183970.0
# 3        197680.0
# 4        194580.0
